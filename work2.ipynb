# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import math
import re
import sys
import csv
import os
from progressbar import *

# %%
v1= pd.read_csv('winemag-data_first150k.csv')
v2 = pd.read_csv('winemag-data-130k-v2.csv')
data = pd.concat([v1, v2], ignore_index=True, sort=False)

# %%
data
# Out:
#         Unnamed: 0  country  \
# 0                0       US
# 1                1    Spain
# 2                2       US
# 3                3       US
# 4                4   France
# ...            ...      ...
# 280896      129966  Germany
# 280897      129967       US
# 280898      129968   France
# 280899      129969   France
# 280900      129970   France
#
#                                               description  \
# 0       This tremendous 100% varietal wine hails from ...
# 1       Ripe aromas of fig, blackberry and cassis are ...
# 2       Mac Watson honors the memory of a wine once ma...
# 3       This spent 20 months in 30% new French oak, an...
# 4       This is the top wine from La Bégude, named aft...
# ...                                                   ...
# 280896  Notes of honeysuckle and cantaloupe sweeten th...
# 280897  Citation is given as much as a decade of bottl...
# 280898  Well-drained gravel soil gives this wine its c...
# 280899  A dry style of Pinot Gris, this is crisp with ...
# 280900  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 0                            Martha's Vineyard      96  235.0      California
# 1         Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2                Special Selected Late Harvest      96   90.0      California
# 3                                      Reserve      96   65.0          Oregon
# 4                                   La Brûlade      95   66.0        Provence
# ...                                        ...     ...    ...             ...
# 280896  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 280897                                     NaN      90   75.0          Oregon
# 280898                                   Kritt      90   30.0          Alsace
# 280899                                     NaN      90   32.0          Alsace
# 280900           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                  region_1           region_2             variety  \
# 0             Napa Valley               Napa  Cabernet Sauvignon
# 1                    Toro                NaN       Tinta de Toro
# 2          Knights Valley             Sonoma     Sauvignon Blanc
# 3       Willamette Valley  Willamette Valley          Pinot Noir
# 4                  Bandol                NaN  Provence red blend
# ...                   ...                ...                 ...
# 280896                NaN                NaN            Riesling
# 280897             Oregon       Oregon Other          Pinot Noir
# 280898             Alsace                NaN      Gewürztraminer
# 280899             Alsace                NaN          Pinot Gris
# 280900             Alsace                NaN      Gewürztraminer
#
#                                           winery         taster_name  \
# 0                                          Heitz                 NaN
# 1                        Bodega Carmen Rodríguez                 NaN
# 2                                       Macauley                 NaN
# 3                                          Ponzi                 NaN
# 4                           Domaine de la Bégude                 NaN
# ...                                          ...                 ...
# 280896  Dr. H. Thanisch (Erben Müller-Burggraef)  Anna Lee C. Iijima
# 280897                                  Citation        Paul Gregutt
# 280898                           Domaine Gresser          Roger Voss
# 280899                      Domaine Marcel Deiss          Roger Voss
# 280900                          Domaine Schoffit          Roger Voss
#
#        taster_twitter_handle  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 280896                   NaN
# 280897           @paulgwine
# 280898            @vossroger
# 280899            @vossroger
# 280900            @vossroger
#
#                                                     title
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 280896  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 280897                  Citation 2004 Pinot Noir (Oregon)
# 280898  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 280899      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 280900  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
# [280901 rows x 14 columns]

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280901 entries, 0 to 280900
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                280833 non-null  object
#  1   description            280901 non-null  object
#  2   designation            197701 non-null  object
#  3   points                 280901 non-null  int64
#  4   price                  258210 non-null  float64
#  5   province               280833 non-null  object
#  6   region_1               234594 non-null  object
#  7   region_2               111464 non-null  object
#  8   variety                280900 non-null  object
#  9   winery                 280901 non-null  object
#  10  taster_name            103727 non-null  object
#  11  taster_twitter_handle  98758 non-null   object
#  12  title                  129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 27.9+ MB

# %%
wine=data.drop(labels='Unnamed: 0', axis=1)

wine.isnull().sum()
# Out:
# country                      68
# description                   0
# designation               83200
# points                        0
# price                     22691
# province                     68
# region_1                  46307
# region_2                 169437
# variety                       1
# winery                        0
# taster_name              177174
# taster_twitter_handle    182143
# title                    150930
# dtype: int64

# %%
dataset = []

feature_names = ["country", "points", "price", 
                     "province", "region_1", "region_2", "variety","winery"]
wine1 = wine[feature_names]
wine1 = wine1.dropna(how = 'any')
wine1.dropna(axis=0,inplace=False)


#print(np.isnan(wine1).any())
rows = wine1.values.tolist()
print(rows[5])
for data_line in rows:
    data_set = []
    for i,value in enumerate(data_line):
        if not value:
            data_set.append((feature_names[i], 'NA'))
        else:           
            data_set.append((feature_names[i], value))             
    dataset.append(data_set)
# Out:
# ['US', 95, 48.0, 'Oregon', 'Ribbon Ridge', 'Willamette Valley', 'Pinot Noir', 'Patricia Green Cellars']

# %%
def new_set(dataset):
    ns = []
    progress = ProgressBar()
    for data in progress(dataset):
        for item in data:
            if [item] not in C1:
                ns.append([item])
    print("success")
    return [frozenset(item) for item in ns]

# %%
def filter_d(dataset, Ck):
    Ck_count = dict()
    for data in dataset:
        for cand in Ck:
            if cand.issubset(data):
                if cand not in Ck_count:
                    Ck_count[cand] = 1
                else:
                    Ck_count[cand] += 1

    num_items = float(len(dataset))
    return_list = []
    support_data = dict()
    for key in Ck_count:
        support  = Ck_count[key] / num_items
        if support >= 0.1:
              return_list.insert(0, key)
        support_data[key] = support
    return return_list, support_data

# %%
def concat(Lk, k):
        return_list = []
        len_Lk = len(Lk)
        for i in range(len_Lk):
            for j in range(i+1, len_Lk):
                L1 = list(Lk[i])[:k-2]
                L2 = list(Lk[j])[:k-2]
                L1.sort()
                L2.sort()
                if L1 == L2:
                    return_list.append(Lk[i] | Lk[j])
        return return_list

# %%
def apriori(dataset):
    C1 = new_set(dataset)
    dataset = [set(data) for data in dataset]
    L1, support_data = filter_d(dataset, C1)
    L = [L1]
    k = 2
    while len(L[k-2]) > 0:
        Ck = concat(L[k-2], k)
        Lk, support_k = filter_d(dataset, Ck)
        support_data.update(support_k)
        L.append(Lk)
        k += 1
    return L, support_data

# %%
freq_set, sup_rata = apriori(dataset)
sup_rata_out = sorted(sup_rata.items(), key=lambda d: d[1], reverse=True)
# Out:
# 100% |########################################################################|
# Created success

# %%
freq_set_file = open(os.path.join('E:', 'fterms.json'), 'w')
for (key, value) in sup_rata_out:
            result_dict = {'set': None, 'sup': None}
            set_result = list(key)
            sup_result = value
            if sup_result < 0.1:
                continue
            result_dict['set'] = set_result
            result_dict['sup'] = sup_result
            json_str = json.dumps(result_dict, ensure_ascii=False)
            freq_set_file.write(json_str + '\n')
freq_set_file.close()

# %%
with open("E:/fterms.json") as f1:
  freq = [json.loads(each) for each in f1.readlines()]
  freq_sup = [each["sup"] for each in freq]
  plt.figure()
  plt.title("Frequent item")
  plt.boxplot(freq_sup)
  plt.show()

# %%
freq
# Out:
# [{'set': [['country', 'US']], 'sup': 1.0},
#  {'set': [['province', 'California']], 'sup': 0.7036379689358175},
#  {'set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.7036379689358175},
#  {'set': [['region_2', 'Central Coast']], 'sup': 0.21588165339291507},
#  {'set': [['region_2', 'Central Coast'], ['province', 'California']],
#   'sup': 0.21588165339291507},
#  {'set': [['region_2', 'Central Coast'], ['country', 'US']],
#   'sup': 0.21588165339291507},
#  {'set': [['region_2', 'Central Coast'],
#    ['country', 'US'],
#    ['province', 'California']],
#   'sup': 0.21588165339291507},
#  {'set': [['region_2', 'Sonoma']], 'sup': 0.18219575480197484},
#  {'set': [['province', 'California'], ['region_2', 'Sonoma']],
#   'sup': 0.18219575480197484},
#  {'set': [['country', 'US'], ['region_2', 'Sonoma']],
#   'sup': 0.18219575480197484},
#  {'set': [['province', 'California'],
#    ['country', 'US'],
#    ['region_2', 'Sonoma']],
#   'sup': 0.18219575480197484},
#  {'set': [['variety', 'Pinot Noir']], 'sup': 0.1728170384518361},
#  {'set': [['variety', 'Pinot Noir'], ['country', 'US']],
#   'sup': 0.1728170384518361},
#  {'set': [['province', 'Washington']], 'sup': 0.1645554794767379},
#  {'set': [['province', 'Washington'], ['country', 'US']],
#   'sup': 0.1645554794767379},
#  {'set': [['region_2', 'Columbia Valley']], 'sup': 0.1545100724350427},
#  {'set': [['region_2', 'Columbia Valley'], ['province', 'Washington']],
#   'sup': 0.1545100724350427},
#  {'set': [['region_2', 'Columbia Valley'], ['country', 'US']],
#   'sup': 0.1545100724350427},
#  {'set': [['region_2', 'Columbia Valley'],
#    ['province', 'Washington'],
#    ['country', 'US']],
#   'sup': 0.1545100724350427},
#  {'set': [['variety', 'Cabernet Sauvignon']], 'sup': 0.1444106093913294},
#  {'set': [['country', 'US'], ['variety', 'Cabernet Sauvignon']],
#   'sup': 0.1444106093913294},
#  {'set': [['region_2', 'Napa']], 'sup': 0.14038343724098165},
#  {'set': [['region_2', 'Napa'], ['province', 'California']],
#   'sup': 0.14038343724098165},
#  {'set': [['region_2', 'Napa'], ['country', 'US']],
#   'sup': 0.14038343724098165},
#  {'set': [['region_2', 'Napa'], ['province', 'California'], ['country', 'US']],
#   'sup': 0.14038343724098165},
#  {'set': [['variety', 'Chardonnay']], 'sup': 0.12920285415690655},
#  {'set': [['variety', 'Chardonnay'], ['country', 'US']],
#   'sup': 0.12920285415690655},
#  {'set': [['points', 87]], 'sup': 0.1267613247324228},
#  {'set': [['country', 'US'], ['points', 87]], 'sup': 0.1267613247324228},
#  {'set': [['variety', 'Pinot Noir'], ['province', 'California']],
#   'sup': 0.12491441133013802},
#  {'set': [['variety', 'Pinot Noir'],
#    ['province', 'California'],
#    ['country', 'US']],
#   'sup': 0.12491441133013802},
#  {'set': [['points', 88]], 'sup': 0.11611229233485891},
#  {'set': [['points', 88], ['country', 'US']], 'sup': 0.11611229233485891},
#  {'set': [['province', 'California'], ['variety', 'Cabernet Sauvignon']],
#   'sup': 0.1156257883166961},
#  {'set': [['province', 'California'],
#    ['country', 'US'],
#    ['variety', 'Cabernet Sauvignon']],
#   'sup': 0.1156257883166961},
#  {'set': [['points', 90]], 'sup': 0.11347255756964215},
#  {'set': [['points', 90], ['country', 'US']], 'sup': 0.11347255756964215},
#  {'set': [['province', 'California'], ['variety', 'Chardonnay']],
#   'sup': 0.10306677718115968},
#  {'set': [['province', 'California'],
#    ['variety', 'Chardonnay'],
#    ['country', 'US']],
#   'sup': 0.10306677718115968}]

# %%
def new_rules(L, support_data):
        big_rules_list = []
        for i in range(1, len(L)):
            for freq_set in L[i]:
                H1 = [frozenset([item]) for item in freq_set]
                if i > 1:
                    rules_map(freq_set, H1, support_data, big_rules_list)
                else:
                    estimite(freq_set, H1, support_data, big_rules_list)
        return big_rules_list

def rules_map(freq_set, H, support_data, big_rules_list):
        m = len(H[0])
        if len(freq_set) > (m+1):
            Hmp1 = concat(H, m+1)
            Hmp1 = estimite(freq_set, Hmp1, support_data, big_rules_list)
            if len(Hmp1) > 1:
                rules_map(freq_set, Hmp1, support_data, big_rules_list)

def estimite(freq_set, H, support_data, big_rules_list):
        prunedH = []
        for conseq in H:
            sup = support_data[freq_set]
            conf = sup / support_data[freq_set - conseq]
            lift = conf / support_data[freq_set - conseq]
            jaccard = sup / (support_data[freq_set - conseq] + support_data[conseq] - sup)
            if conf >= 0.5:
                big_rules_list.append((freq_set-conseq, conseq, sup, conf, lift,jaccard))
                prunedH.append(conseq)
        return prunedH

# %%
strong_rules_list = generate_rules(freq_set, sup_rata)
strong_rules_list = sorted(strong_rules_list, key=lambda x: x[3], reverse=True)
rules_file = open(os.path.join('F:', 'rules.json'), 'w')
for result in strong_rules_list:
            result_dict = {'X_set': None, 'Y_set': None, 'sup': None, 'conf': None, 'lift': None, 'jaccard': None}
            X_set, Y_set, sup, conf, lift, jaccard = result
            result_dict['X_set'] = list(X_set)
            result_dict['Y_set'] = list(Y_set)
            result_dict['sup'] = sup
            result_dict['conf'] = conf
            result_dict['lift'] = lift
            result_dict['jaccard'] = jaccard
            json_str = json.dumps(result_dict, ensure_ascii=False)
            rules_file.write(json_str + '\n')
rules_file.close()

# %%
with open("F:/rules.json") as f2:
  rules = [json.loads(each) for each in f2.readlines()]
  rules_sup = [each["sup"] for each in rules]
  rules_conf = [each["conf"] for each in rules]
  fig=plt.figure("rule")
  ax=fig.add_axes([0.1,0.1,0.8,0.8])
  ax.set_title("Rules")
  ax.scatter(rules_sup, rules_conf, marker='o', color='blue')
  ax.set_xlabel("Support")
  ax.set_ylabel("Confidence")
  plt.show()

# %%
rules
# Out:
# [{'X_set': [['points', 87]],
#   'Y_set': [['country', 'US']],
#   'sup': 0.1267613247324228,
#   'conf': 1.0,
#   'lift': 7.888841506751954,
#   'jaccard': 0.1267613247324228},
#  {'X_set': [['points', 88]],
#   'Y_set': [['country', 'US']],
#   'sup': 0.11611229233485891,
#   'conf': 1.0,
#   'lift': 8.612352576039727,
#   'jaccard': 0.11611229233485891},
#  {'X_set': [['points', 90]],
#   'Y_set': [['country', 'US']],
#   'sup': 0.11347255756964215,
#   'conf': 1.0,
#   'lift': 8.812703453751489,
#   'jaccard': 0.11347255756964215},
#  {'X_set': [['province', 'Washington']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.1645554794767379,
#   'conf': 1.0,
#   'lift': 6.076977826444018,
#   'jaccard': 0.1645554794767379},
#  {'X_set': [['region_2', 'Columbia Valley']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.1545100724350427,
#   'conf': 1.0,
#   'lift': 6.472069970845482,
#   'jaccard': 0.1545100724350427},
#  {'X_set': [['region_2', 'Columbia Valley']],
#   'Y_set': [['province', 'Washington']],
#   'sup': 0.1545100724350427,
#   'conf': 1.0,
#   'lift': 6.472069970845482,
#   'jaccard': 0.9389542841500136},
#  {'X_set': [['region_2', 'Central Coast']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.21588165339291507,
#   'conf': 1.0,
#   'lift': 4.632167598697938,
#   'jaccard': 0.21588165339291507},
#  {'X_set': [['region_2', 'Central Coast']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.21588165339291507,
#   'conf': 1.0,
#   'lift': 4.632167598697938,
#   'jaccard': 0.30680785137194144},
#  {'X_set': [['variety', 'Chardonnay']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.12920285415690655,
#   'conf': 1.0,
#   'lift': 7.7397671013179,
#   'jaccard': 0.12920285415690655},
#  {'X_set': [['variety', 'Pinot Noir']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.1728170384518361,
#   'conf': 1.0,
#   'lift': 5.786466478990721,
#   'jaccard': 0.1728170384518361},
#  {'X_set': [['region_2', 'Sonoma']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.18219575480197484,
#   'conf': 1.0,
#   'lift': 5.488602086732929,
#   'jaccard': 0.18219575480197484},
#  {'X_set': [['region_2', 'Sonoma']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.18219575480197484,
#   'conf': 1.0,
#   'lift': 5.488602086732929,
#   'jaccard': 0.25893394450775276},
#  {'X_set': [['province', 'California']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.7036379689358175,
#   'conf': 1.0,
#   'lift': 1.42118538815124,
#   'jaccard': 0.7036379689358176},
#  {'X_set': [['region_2', 'Napa']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.14038343724098165,
#   'conf': 1.0,
#   'lift': 7.123347452188423,
#   'jaccard': 0.14038343724098168},
#  {'X_set': [['region_2', 'Napa']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.14038343724098165,
#   'conf': 1.0,
#   'lift': 7.123347452188423,
#   'jaccard': 0.19951088974532974},
#  {'X_set': [['variety', 'Cabernet Sauvignon']],
#   'Y_set': [['country', 'US']],
#   'sup': 0.1444106093913294,
#   'conf': 1.0,
#   'lift': 6.924698983093144,
#   'jaccard': 0.14441060939132944},
#  {'X_set': [['region_2', 'Columbia Valley']],
#   'Y_set': [['province', 'Washington'], ['country', 'US']],
#   'sup': 0.1545100724350427,
#   'conf': 1.0,
#   'lift': 6.472069970845482,
#   'jaccard': 0.9389542841500136},
#  {'X_set': [['region_2', 'Central Coast']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.21588165339291507,
#   'conf': 1.0,
#   'lift': 4.632167598697938,
#   'jaccard': 0.30680785137194144},
#  {'X_set': [['region_2', 'Sonoma']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.18219575480197484,
#   'conf': 1.0,
#   'lift': 5.488602086732929,
#   'jaccard': 0.25893394450775276},
#  {'X_set': [['region_2', 'Napa']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.14038343724098165,
#   'conf': 1.0,
#   'lift': 7.123347452188423,
#   'jaccard': 0.19951088974532974},
#  {'X_set': [['province', 'Washington']],
#   'Y_set': [['region_2', 'Columbia Valley']],
#   'sup': 0.1545100724350427,
#   'conf': 0.9389542841500136,
#   'lift': 5.706004364824249,
#   'jaccard': 0.9389542841500136},
#  {'X_set': [['province', 'Washington']],
#   'Y_set': [['region_2', 'Columbia Valley'], ['country', 'US']],
#   'sup': 0.1545100724350427,
#   'conf': 0.9389542841500136,
#   'lift': 5.706004364824249,
#   'jaccard': 0.9389542841500136},
#  {'X_set': [['variety', 'Cabernet Sauvignon']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.1156257883166961,
#   'conf': 0.8006737787759686,
#   'lift': 5.544424901679294,
#   'jaccard': 0.1578675457587089},
#  {'X_set': [['variety', 'Cabernet Sauvignon']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.1156257883166961,
#   'conf': 0.8006737787759686,
#   'lift': 5.544424901679294,
#   'jaccard': 0.1578675457587089},
#  {'X_set': [['variety', 'Chardonnay']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.10306677718115968,
#   'conf': 0.7977128512656022,
#   'lift': 6.174111682524007,
#   'jaccard': 0.14123108071405643},
#  {'X_set': [['variety', 'Chardonnay']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.10306677718115968,
#   'conf': 0.7977128512656022,
#   'lift': 6.174111682524007,
#   'jaccard': 0.14123108071405643},
#  {'X_set': [['variety', 'Pinot Noir']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.12491441133013802,
#   'conf': 0.7228130539047023,
#   'lift': 4.182533506996473,
#   'jaccard': 0.1662111294924357},
#  {'X_set': [['variety', 'Pinot Noir']],
#   'Y_set': [['province', 'California'], ['country', 'US']],
#   'sup': 0.12491441133013802,
#   'conf': 0.7228130539047023,
#   'lift': 4.182533506996473,
#   'jaccard': 0.1662111294924357},
#  {'X_set': [['country', 'US']],
#   'Y_set': [['province', 'California']],
#   'sup': 0.7036379689358175,
#   'conf': 0.7036379689358175,
#   'lift': 0.7036379689358175,
#   'jaccard': 0.7036379689358176}]
